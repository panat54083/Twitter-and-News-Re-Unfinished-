# %%
import tweepy

# %%
consumer_key = "g3e43rSvKAuPWkdFDCB4zef4l"
consumer_secret = "APNEAFhy9SqhmmiGZ5C207h5e521ITX1eqKahnzIDgz71qJYFq"
access_token = "1099897687208423424-5MnR4i4dr7QVJrdclUIl17azR3CuYm"
access_token_secret = "KBpJmAZ8uBzLgC60GPsGv8F8VeEmk43Pn6bCtIDo8ICyW"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
for tweet in tweepy.Cursor(api.search, q='covid').items(1):
    print(tweet)
# Out:
# Status(_api=<tweepy.api.API object at 0x0000020CA8B68F10>, _json={'created_at': 'Sat Apr 02 08:33:58 +0000 2022', 'id': 1510173684601925634, 'id_str': '1510173684601925634', 'text': 'RT @patanna: My friends daughter has been told she must come to work, even though she has a positive test for covid. She is ill and sneezin…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'patanna', 'name': 'anne juliff', 'id': 21480788, 'id_str': '21480788', 'indices': [3, 11]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 15210328, 'id_str': '15210328', 'name': 'Joanna Booth', 'screen_name': 'stillawake', 'location': 'Bristol, UK', 'description': 'Z
# ...
